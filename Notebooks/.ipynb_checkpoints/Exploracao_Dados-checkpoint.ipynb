# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load dataset
dados = pd.read_csv("../Dados/wfp_food_prices_moz.csv")

# %%
#Visualize first 5 lines
dados.head()
# Out:
#       province          district  market  market_id  latitude  longitude  \
# 0  Maputo City  Cidade_De_Maputo  Maputo        321    -25.97      32.59
# 1         Gaza            Chokwe  Chokwe        317    -24.53      32.98
# 2         Gaza            Chokwe  Chokwe        317    -24.53      32.98
# 3  Maputo City  Cidade_De_Maputo  Maputo        321    -25.97      32.59
# 4    Inhambane            Maxixe  Maxixe        331    -23.86      35.35
#
#              category      commodity  commodity_id unit pricetype  price(MZN)  \
# 0  cereals and tubers  Maize (white)            67   KG    Retail        1.34
# 1  cereals and tubers  Maize (white)            67   KG    Retail        1.53
# 2  cereals and tubers  Maize (white)            67   KG    Retail        1.67
# 3  cereals and tubers  Maize (white)            67   KG    Retail        1.86
# 4  cereals and tubers  Maize (white)            67   KG    Retail        2.72
#
#    year  month
# 0  1992     11
# 1  1992     12
# 2  1993      1
# 3  1993      1
# 4  1993      2

# %%
#Visualize last 5 lines
dados.tail()
# Out:
#        province   district             market  market_id  latitude  longitude  \
# 44203  Zambezia  Nicoadala  Nicoadala (rural)       6696    -17.59      36.77
# 44204  Zambezia  Nicoadala  Nicoadala (rural)       6696    -17.59      36.77
# 44205  Zambezia  Nicoadala  Nicoadala (rural)       6696    -17.59      36.77
# 44206  Zambezia  Nicoadala  Nicoadala (rural)       6696    -17.59      36.77
# 44207  Zambezia  Nicoadala  Nicoadala (rural)       6696    -17.59      36.77
#
#                     category       commodity  commodity_id unit pricetype  \
# 44203        pulses and nuts  Beans (butter)           418   KG    Retail
# 44204        pulses and nuts      Groundnuts           153   KG    Retail
# 44205  vegetables and fruits            Kale           796   KG    Retail
# 44206  vegetables and fruits          Onions           173   KG    Retail
# 44207  vegetables and fruits        Tomatoes           114   KG    Retail
#
#        price(MZN)  year  month
# 44203       120.0  2025      1
# 44204       120.0  2025      1
# 44205       100.0  2025      1
# 44206        80.0  2025      1
# 44207        60.0  2025      1

# %%
dados.describe()
# Out:
#           market_id      latitude     longitude  commodity_id    price(MZN)  \
# count  44208.000000  44208.000000  44208.000000  44208.000000  44208.000000
# mean    2256.957904    -18.588532     35.565682    236.179289     95.222808
# std     2791.197098      4.210377      2.370450    166.615454    205.457982
# min      316.000000    -26.340000     32.020000     52.000000      1.010000
# 25%      323.000000    -23.100000     33.640000     87.000000     30.000000
# 50%      333.000000    -17.590000     35.240000    221.000000     50.000000
# 75%     6662.000000    -14.890000     36.990000    355.000000     77.795000
# max     7776.000000    -11.940000     40.620000    804.000000   2450.000000
#
#                year         month
# count  44208.000000  44208.000000
# mean    2016.908365      6.216703
# std        5.648390      3.316089
# min     1992.000000      1.000000
# 25%     2013.000000      4.000000
# 50%     2019.000000      6.000000
# 75%     2021.000000      9.000000
# max     2025.000000     12.000000

# %%
# Dataset informations
print("Dimensoes:", dados.shape)
print("Colunas:", dados.columns.tolist())
print("Tipos de dados:\n", dados.dtypes)
# Out:
# Dimensoes: (44208, 14)
# Colunas: ['province', 'district', 'market', 'market_id', 'latitude', 'longitude', 'category', 'commodity', 'commodity_id', 'unit', 'pricetype', 'price(MZN)', 'year', 'month']
# Tipos de dados:
#  province         object
# district         object
# market           object
# market_id         int64
# latitude        float64
# longitude       float64
# category         object
# commodity        object
# commodity_id      int64
# unit             object
# pricetype        object
# price(MZN)      float64
# year              int64
# month             int64
# dtype: object

# %%
# Check for null values
print("\nValores nulos por coluna:")
print(dados.isnull().sum())
# Out:
# Valores nulos por coluna:
# province        0
# district        0
# market          0
# market_id       0
# latitude        0
# longitude       0
# category        0
# commodity       0
# commodity_id    0
# unit            0
# pricetype       0
# price(MZN)      0
# year            0
# month           0
# dtype: int64

# %%
# How many different products?
print("\nProdutos distintos:", dados['commodity'].nunique())
print(dados['commodity'].value_counts())
# Out:
# Produtos distintos: 53
# commodity
# Maize (white)                       3752
# Rice (imported)                     2872
# Sugar (brown, local)                2804
# Oil (vegetable, local)              2697
# Cowpeas                             2368
# Rice                                2261
# Wheat flour (local)                 2067
# Maize meal (white, first grade)     1959
# Beans (butter)                      1916
# Groundnuts (small, shelled)         1671
# Beans (dry)                         1514
# Groundnuts (large, shelled)         1403
# Beans (catarino)                    1230
# Maize meal (white, without bran)    1161
# Maize meal (white, with bran)        862
# Onions                               679
# Cabbage                              647
# Oil (vegetable)                      631
# Salt (iodised)                       626
# Tomatoes                             625
# Beans (magnum)                       616
# Sugar                                613
# Sweet potatoes                       583
# Groundnuts (Mix)                     580
# Coconut                              580
# Potatoes                             578
# Eggs                                 576
# Handwash soap                        573
# Kale                                 563
# Garlic                               534
# Rice (local)                         531
# Groundnuts                           525
# Carrots                              487
# Fish                                 478
# Firewood                             460
# Cassava leaves                       435
# Maize meal                           411
# Oil (vegetable, imported)            279
# Cassava (dry)                        229
# Cassava flour                        208
# Sugar (brown, imported)              142
# Beans (red)                           77
# Onions (local)                        55
# Peppers (green)                       53
# Potatoes (Irish, local)               52
# Cassava (fresh)                       49
# Garlic (small)                        49
# Garlic (large)                        48
# Beans (fresh)                         35
# Potatoes (Irish, imported)            27
# Sesame                                21
# Soybeans                              15
# Maize (imported)                       1
# Name: count, dtype: int64

# %%
# How many different marketss?
print("\nMercados distintos:", dados['market'].nunique())
# Out:
# Mercados distintos: 98

# %%
# Years available
print("\nAnos no dataset:", sorted(df['year'].unique()))
# Out:
# Anos no dataset: [np.int64(1992), np.int64(1993), np.int64(1994), np.int64(1995), np.int64(1996), np.int64(1997), np.int64(1998), np.int64(1999), np.int64(2000), np.int64(2001), np.int64(2002), np.int64(2003), np.int64(2004), np.int64(2005), np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2009), np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024), np.int64(2025)]

# %%
# Criate date column
dados['date'] = pd.to_datetime(dados['year'].astype(str) + '-' + dados['month'].astype(str) + '-01')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9580\3241778804.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['date'] = pd.to_datetime(dados['year'].astype(str) + '-' + dados['month'].astype(str) + '-01')

# %%
# Median price evolution over time
precos_mensais = dados.groupby('date')['price(MZN)'].mean().reset_index()
plt.figure(figsize=(10,4))
plt.plot(precos_mensais['date'], precos_mensais['price(MZN)'], color='green')
plt.title('Preço Médio dos Produtos Agrícolas ao Longo do Tempo (MZN)')
plt.xlabel('Ano')
plt.ylabel('Preço Médio (MZN)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Top 3 more frequent products
top_produtos = dados['commodity'].value_counts().head(3).index

plt.figure(figsize=(12,6))
for produto in top_produtos:
    dado = dados[dados['commodity'] == produto]
    serie = dado.groupby('date')['price(MZN)'].mean()
    plt.plot(serie, label=produto)

plt.title('Evolução do Preço por Produto (Top 3)')
plt.xlabel('Ano')
plt.ylabel('Preço Médio (MZN)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
